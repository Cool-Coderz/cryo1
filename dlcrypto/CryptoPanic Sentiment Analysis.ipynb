# %%
# Deep learning network for selecting top cryptocurrencys
# Get all news from cryptopanic. Sort by votes. Store historical in database.
# Metric for measuring will be price/volume
# 4fe852ad2c67efa04015bb737a637dbe39197808 
import pandas as pd
import requests

# %%
url = 'https://cryptopanic.com/api/posts/?auth_token=4fe852ad2c67efa04015bb737a637dbe39197808' # All API methods are rate limited per IP at 5req/sec.
r = requests.get(url)
x = r.json()
df = pd.DataFrame(x['results'])

# %%
df
# Out:
#               created_at                                         currencies  \
# 0   2018-11-13T09:44:32Z                                                NaN
# 1   2018-11-13T09:43:19Z  [{'code': 'XEM', 'title': 'NEM', 'slug': 'nem'...
# 2   2018-11-13T09:37:20Z  [{'code': 'ETH', 'title': 'Ethereum', 'slug': ...
# 3   2018-11-13T09:28:30Z  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...
# 4   2018-11-13T09:15:56Z  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...
# 5   2018-11-13T09:00:53Z                                                NaN
# 6   2018-11-13T09:00:52Z  [{'code': 'ETH', 'title': 'Ethereum', 'slug': ...
# 7   2018-11-13T09:00:49Z  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...
# 8   2018-11-13T09:00:34Z  [{'code': 'XRP', 'title': 'XRP', 'slug': 'ripp...
# 9   2018-11-13T09:00:05Z                                                NaN
# 10  2018-11-13T08:59:30Z  [{'code': 'BTC', 'title': 'Bitcoin', 'slug': '...
# ...
